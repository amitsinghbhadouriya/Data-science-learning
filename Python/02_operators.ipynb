# %%
# Operators

# %%
# Arithmetic operators

# %%
a = 10
b = 5

# %%
a + b  # Addition
# Out:
# 15

# %%
a - b  # Subtraction
# Out:
# 5

# %%
a * b  # Multiplication
# Out:
# 50

# %%
a / b  # Divide
# Out:
# 2.0

# %%
a % b  # Modulo
# Out:
# 0

# %%
# Assignment operators

# %%
c = 4

# %%
c += 1
c
# Out:
# 5

# %%
c -= 2
c
# Out:
# 3

# %%
# Comparison operators

# %%
e = 9
f = 8

# %%
e == f    # double equals
# Out:
# False

# %%
e > f     # Greater
# Out:
# True

# %%
e < f     # Smaller
# Out:
# False

# %%
# Logical
