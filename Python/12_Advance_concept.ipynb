# %%
# Map
numbers = (1,2,3,4,5,6)
square = list(map(lambda x: x**2, numbers))
print(square)
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
# Filter
numbers = (1,2,3,4,5,6)
even_num = list(filter(lambda x: x%2 == 0, numbers))
print(even_num)
# Out:
# [2, 4, 6]

# %%
# Reduce
from functools import reduce
numbers = (1,2,3,4,5,6)
sum = reduce(lambda x, y : x+y, numbers)
print(sum)
# Out:
# 21

# %%
# without Walrus Operator
data = input("Enter a value (or 'quit' to exit): ")
while data != "quit":
    print(f"You entered: {data}")
    data = input("Enter a value (or 'quit' to exit): ")
# Out:
# Enter a value (or 'quit' to exit):  34
# You entered: 34
# Enter a value (or 'quit' to exit):  23
# You entered: 23
# Enter a value (or 'quit' to exit):  q
# You entered: q
# Enter a value (or 'quit' to exit):  quit

# %%
# Walrus operator
while(data := input("Enter a value (or 'quit' to exit): ") != "quit"):
    print(f"You entered: {data}")
# Out:
# Enter a value (or 'quit' to exit):  34
# You entered: True
# Enter a value (or 'quit' to exit):  55
# You entered: True
# Enter a value (or 'quit' to exit):  32
# You entered: True
# Enter a value (or 'quit' to exit):  quit

# %%
# Args and Kwargs

# %%
# *Args (Positional Arguments)
def my_function(*args):
    print(type(args))
    for arg in args:
        print(arg)

my_function(1,2,3, "Hello")
# Out:
# <class 'tuple'>
# 1
# 2
# 3
# Hello

# %%
# **Kwargs (Keyword Arguments)
def my_function(**kwargs):
    print(type(kwargs))
    for key, value in kwargs.items():
        print(f"{key}: {value}")

my_function(name="Amit", age=21, city="Gwalior")
# Out:
# <class 'dict'>
# name: Amit
# age: 21
# city: Gwalior

# %%
# Requests Module - Working with APIs
import requests
url = "https://api.github.com/users/octocat"
response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
# Out:
# {'login': 'octocat', 'id': 583231, 'node_id': 'MDQ6VXNlcjU4MzIzMQ==', 'avatar_url': 'https://avatars.githubusercontent.com/u/583231?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/octocat', 'html_url': 'https://github.com/octocat', 'followers_url': 'https://api.github.com/users/octocat/followers', 'following_url': 'https://api.github.com/users/octocat/following{/other_user}', 'gists_url': 'https://api.github.com/users/octocat/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/octocat/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/octocat/subscriptions', 'organizations_url': 'https://api.github.com/users/octocat/orgs', 'repos_url': 'https://api.github.com/users/octocat/repos', 'events_url': 'https://api.github.com/users/octocat/events{/privacy}', 'received_events_url': 'https://api.github.com/users/octocat/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False, 'name': 'The Octocat', 'company': '@github', 'blog': 'https://github.blog', 'location': 'San Francisco', 'email': None, 'hireable': None, 'bio': None, 'twitter_username': None, 'public_repos': 8, 'public_gists': 8, 'followers': 23781, 'following': 9, 'created_at': '2011-01-25T18:44:36Z', 'updated_at': '2026-08-22T11:33:34Z'}

# %%
# Multithreading
import threading
import time
def worker(num):
    print(f"Thread {num}: starting")
    time.sleep(2)
    print(f"Thread {num}: finishing")
threads = []
for i in range(3):
    thread = threading.Thread(target=worker, args=(i,))
    threads.append(thread)
    thread.start()
for thread in threads:
    thread.join()
print("All threads completed.")
# Out:
# Thread 0: starting
# Thread 1: starting
# Thread 2: starting
# Thread 0: finishing
# Thread 1: finishing
# Thread 2: finishing
# All threads completed.
