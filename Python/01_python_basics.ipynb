# %%
# Variables

# %%
name = "Amit"
age = 21

# %%
name
# Out:
# 'Amit'

# %%
age
# Out:
# 21

# %%
# Data Types

# %%
# integer
a = 21

# %%
a
# Out:
# 21

# %%
# float
b = 22.2

# %%
b
# Out:
# 22.2

# %%
# Strings
name = "Amit"

# %%
name
# Out:
# 'Amit'

# %%
# Boolean
z = True

# %%
z
# Out:
# True

# %%
# Type casting

# %%
x = int("5")

# %%
type(x)
# Out:
# int

# %%
x
# Out:
# 5

# %%
# Input

# %%
a = int(input("Enter a number: "))
# Out:
# Enter a number:  3

# %%
type(a)
# Out:
# int

# %%
a
# Out:
# 3
